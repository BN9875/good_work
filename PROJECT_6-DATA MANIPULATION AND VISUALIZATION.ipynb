# %% [markdown]
# ## Importing pandas Library

# %%
import pandas as pd

# %% [markdown]
# ## Reading Data

# %%
brics_data = pd.read_csv('Project_6-brics.csv')

# %%
marks_data = pd.read_csv('Project_6-marks.csv')

# %%
cars_data = pd.read_csv('Project_6-cars.csv')

# %%
mtc_data = pd.read_csv('Project_6-mtcars.csv')

# %%
brics_data
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
print(brics_data)
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
print(type(brics_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Exploring data

# %%
brics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   code        5 non-null      object
#  1   country     5 non-null      object
#  2   population  5 non-null      int64
#  3   area        5 non-null      int64
#  4   capital     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 328.0+ bytes

# %%
brics_data.value_counts()
# Out:
# code  country       population  area      capital
# SA    South Africa  55          1221037   Pretoria     1
# RU    Russia        144         17098242  Moscow       1
# IN    India         1252        3287590   New Delhi    1
# CH    China         1357        9596961   Beijing      1
# BR    Brazil        200         8515767   Brasilia     1
# dtype: int64

# %%
brics_data.sort_values(by=['code'])
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %%
brics_data
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# ** The dataframe is only changed for that particular cell.
# ** The change is not permanent.

# %%
# Sorting data based on population
brics_data.sort_values(by=['population'], ascending = False)
# Out:
#   code       country  population      area    capital
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# ** China has the largest population

# %%
# Sorting countries by size
brics_data.sort_values(by=['area'], ascending = False)
# Out:
#   code       country  population      area    capital
# 1   RU        Russia         144  17098242     Moscow
# 3   CH         China        1357   9596961    Beijing
# 0   BR        Brazil         200   8515767   Brasilia
# 2   IN         India        1252   3287590  New Delhi
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# ** Russia has the largest area.

# %%
# Printing and sorting single column
brics_data.country.sort_values(ascending = False)
# Out:
# 4    South Africa
# 1          Russia
# 2           India
# 3           China
# 0          Brazil
# Name: country, dtype: object

# %%
# Printing and sorting area in descending
brics_data[['country','area']].sort_values(by='area', ascending = False)
# Out:
#         country      area
# 1        Russia  17098242
# 3         China   9596961
# 0        Brazil   8515767
# 2         India   3287590
# 4  South Africa   1221037

# %%
# Printing area column
print(brics_data['area'])
# Out:
# 0     8515767
# 1    17098242
# 2     3287590
# 3     9596961
# 4     1221037
# Name: area, dtype: int64

# %%
# printing code column
brics_data.code
# Out:
# 0    BR
# 1    RU
# 2    IN
# 3    CH
# 4    SA
# Name: code, dtype: object

# %%
# Print country, capital and popluation
brics_data[['country','capital','population']]
# Out:
#         country    capital  population
# 0        Brazil   Brasilia         200
# 1        Russia     Moscow         144
# 2         India  New Delhi        1252
# 3         China    Beijing        1357
# 4  South Africa   Pretoria          55

# %%
df = pd.DataFrame({'name': ['Niko', 'Penelope', 'Aria'], 'average score': [10, 5, 3], 'max': [99, 100, 3]})

df.name
# Out:
# 0        Niko
# 1    Penelope
# 2        Aria
# Name: name, dtype: object

# %%
df['average score']
# Out:
# 0    10
# 1     5
# 2     3
# Name: average score, dtype: int64

# %%
# Setting column 0 as index
brics_data = brics_data.set_index('code')

# %%
brics_data
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %%
brics_data_2 = pd.read_csv('Project_6-brics.csv', index_col = 0)
brics_data_2
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %% [markdown]
# ** Same effect using both methods for reseting index.

# %%
brics_data['on_earth']=['True','True','True','True','True']
brics_data
# Out:
#            country  population      area    capital on_earth
# code
# BR          Brazil         200   8515767   Brasilia     True
# RU          Russia         144  17098242     Moscow     True
# IN           India        1252   3287590  New Delhi     True
# CH           China        1357   9596961    Beijing     True
# SA    South Africa          55   1221037   Pretoria     True

# %%
brics_data['density']=brics_data['population']/brics_data['area']*1000000
brics_data
# Out:
#            country  population      area    capital on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia     True   23.485847
# RU          Russia         144  17098242     Moscow     True    8.421918
# IN           India        1252   3287590  New Delhi     True  380.826076
# CH           China        1357   9596961    Beijing     True  141.398928
# SA    South Africa          55   1221037   Pretoria     True   45.043680

# %%
brics_data.style.set_precision(2)
brics_data
# Out:
#            country  population      area    capital on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia     True   23.485847
# RU          Russia         144  17098242     Moscow     True    8.421918
# IN           India        1252   3287590  New Delhi     True  380.826076
# CH           China        1357   9596961    Beijing     True  141.398928
# SA    South Africa          55   1221037   Pretoria     True   45.043680

# %%
brics_data.density.round(2)
# Out:
# code
# BR     23.49
# RU      8.42
# IN    380.83
# CH    141.40
# SA     45.04
# Name: density, dtype: float64

# %%
brics_data
# Out:
#            country  population      area    capital on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia     True   23.485847
# RU          Russia         144  17098242     Moscow     True    8.421918
# IN           India        1252   3287590  New Delhi     True  380.826076
# CH           China        1357   9596961    Beijing     True  141.398928
# SA    South Africa          55   1221037   Pretoria     True   45.043680

# %%
brics_data.loc['IN']
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# on_earth           True
# density         380.826
# Name: IN, dtype: object

# %%
brics_data.iloc[2]
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# on_earth           True
# density         380.826
# Name: IN, dtype: object

# %%
newrow = {'code':'WK', 'country':'Wakanda', 'population':5,'area':1000000,'capital':'Wakanda City','on_earth':False,'density':5}
brics1 = brics_data.append(newrow,ignore_index=True)

# %%
brics1
# Out:
#         country  population      area       capital on_earth     density code
# 0        Brazil         200   8515767      Brasilia     True   23.485847  NaN
# 1        Russia         144  17098242        Moscow     True    8.421918  NaN
# 2         India        1252   3287590     New Delhi     True  380.826076  NaN
# 3         China        1357   9596961       Beijing     True  141.398928  NaN
# 4  South Africa          55   1221037      Pretoria     True   45.043680  NaN
# 5       Wakanda           5   1000000  Wakanda City    False    5.000000   WK

# %%
brics_data.loc['WK'] = ['Wakanda', 5, 1000000, 'Wakanda City', False, 5]
brics_data
# Out:
#            country  population      area       capital on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia     True   23.485847
# RU          Russia         144  17098242        Moscow     True    8.421918
# IN           India        1252   3287590     New Delhi     True  380.826076
# CH           China        1357   9596961       Beijing     True  141.398928
# SA    South Africa          55   1221037      Pretoria     True   45.043680
# WK         Wakanda           5   1000000  Wakanda City    False    5.000000

# %%
brics_data.loc['US'] = ['USA', 5, 2000000, 'Washington DC', True, 2.5]
brics_data
# Out:
#            country  population      area        capital on_earth     density
# code
# BR          Brazil         200   8515767       Brasilia     True   23.485847
# RU          Russia         144  17098242         Moscow     True    8.421918
# IN           India        1252   3287590      New Delhi     True  380.826076
# CH           China        1357   9596961        Beijing     True  141.398928
# SA    South Africa          55   1221037       Pretoria     True   45.043680
# WK         Wakanda           5   1000000   Wakanda City    False    5.000000
# US             USA           5   2000000  Washington DC     True    2.500000

# %%
brics_data.loc["IN","capital"]
# Out:
# 'New Delhi'

# %%
brics_data["capital"].loc["IN"]
# Out:
# 'New Delhi'

# %%
brics1 = brics_data

# %%
# Deleting columns from the dataframe
brics1 = brics1.drop(['area','density'], axis=1)

# %%
brics1
# Out:
#            country  population        capital on_earth
# code
# BR          Brazil         200       Brasilia     True
# RU          Russia         144         Moscow     True
# IN           India        1252      New Delhi     True
# CH           China        1357        Beijing     True
# SA    South Africa          55       Pretoria     True
# WK         Wakanda           5   Wakanda City    False
# US             USA           5  Washington DC     True

# %%
brics1 = brics_data

# %%
brics1.drop(['WK'], axis=0)
# Out:
#            country  population      area        capital on_earth     density
# code
# BR          Brazil         200   8515767       Brasilia     True   23.485847
# RU          Russia         144  17098242         Moscow     True    8.421918
# IN           India        1252   3287590      New Delhi     True  380.826076
# CH           China        1357   9596961        Beijing     True  141.398928
# SA    South Africa          55   1221037       Pretoria     True   45.043680
# US             USA           5   2000000  Washington DC     True    2.500000

# %%
brics1.drop(['WK','IN'])
# Out:
#            country  population      area        capital on_earth     density
# code
# BR          Brazil         200   8515767       Brasilia     True   23.485847
# RU          Russia         144  17098242         Moscow     True    8.421918
# CH           China        1357   9596961        Beijing     True  141.398928
# SA    South Africa          55   1221037       Pretoria     True   45.043680
# US             USA           5   2000000  Washington DC     True    2.500000

# %% [markdown]
# ## Cars dataset

# %%
# Printing first 7 rows
cars_data.head(7)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
# printing last 5 rows
cars_data.tail(5)
# Out:
#   Unnamed: 0  cars_per_cap  country  drives_right
# 2        JAP           588    Japan         False
# 3         IN            18    India         False
# 4         RU           200   Russia          True
# 5        MOR            70  Morocco          True
# 6         EG            45    Egypt          True

# %%
cars_data.tail(10)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
# Renaming columns
df1  = cars_data.rename(columns={'Unnamed: 0':'Code'}, inplace=False)
df1
# Out:
#   Code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True

# %%
# rem=naming column without creating another dataframe
cars_data.rename( columns={'Unnamed: 0':'code'}, inplace=True )
cars_data
# Out:
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True

# %%
# Setting first column as index
cars_data.set_index('code', inplace=True)

# %%
cars_data
# Out:
#       cars_per_cap        country  drives_right
# code
# US             809  United States          True
# AUS            731      Australia         False
# JAP            588          Japan         False
# IN              18          India         False
# RU             200         Russia          True
# MOR             70        Morocco          True
# EG              45          Egypt          True

# %%
# using code to access rows
cars_data.loc['RU']
# Out:
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object

# %%
print(cars_data.loc[['RU']])
# Out:
#       cars_per_cap country  drives_right
# code
# RU             200  Russia          True

# %%
cars_data.loc[['RU','AUS']]
# Out:
#       cars_per_cap    country  drives_right
# code
# RU             200     Russia          True
# AUS            731  Australia         False

# %%
print(cars_data.loc['IN'][0])
# Out:
# 18

# %%
print(cars_data['cars_per_cap'].loc[['IN','RU']])
# Out:
# code
# IN     18
# RU    200
# Name: cars_per_cap, dtype: int64

# %% [markdown]
# ## Marks dataframe

# %%
# Finding shape of dataframe
marks_data.shape
# Out:
# (20, 7)

# %%
marks_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      20 non-null     object
#  1   Student_Name    20 non-null     object
#  2   English         20 non-null     float64
#  3   Maths           20 non-null     float64
#  4   Science         20 non-null     float64
#  5   History         20 non-null     float64
#  6   Social_Studies  20 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.2+ KB

# %%
print(type(marks_data))
print(type(marks_data.English))  # Column's dtype is Series, the dtype of the values is Object.
print(type(5))
print(type(5.5))
print(type("Python"))
print(type(True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(marks_data)
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# ...

# %%
display(marks_data)
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# ...

# %%
marks_data
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# ...

# %%
display(marks_data[marks_data['Student_Name']=='David'])
# Out:
#   Student_ID Student_Name    English      Maths    Science    History  \
# 3        S04        David  21.160844  95.052971  35.860852  62.865185
#
#    Social_Studies
# 3       95.264572

# %%
marks_data[(marks_data['Student_Name']=='David') | (marks_data['Student_Name']=='Ria')]
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
#
#     Social_Studies
# 3        95.264572
# 17        7.305670

# %%
marks_data[(marks_data['Student_ID']=='S05') | (marks_data['Student_ID']=='S10')]
# Out:
#   Student_ID Student_Name    English      Maths   Science    History  \
# 4        S05       Edward  63.250994  60.693247  7.020915  60.505272
# 9        S10         John  30.968731  14.282925  3.312853  79.916094
#
#    Social_Studies
# 4       34.041671
# 9       32.706891

# %%
marks_data[(marks_data['English']>70) | (marks_data['Maths']>70)]
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 3        95.264572
# 5        85.019761
# 8        90.483635
# 11       71.930382
# 13       20.583259
# 15       74.528425
# ...

# %%
marks_data[(marks_data['English']>70) & (marks_data['Maths']>70)]
# Out:
#    Student_ID Student_Name    English      Maths   Science    History  \
# 18        S19        Suvin  72.218179  85.284128  32.55506  47.007177
#
#     Social_Studies
# 18       83.344403

# %%
marks_data[(marks_data['Student_Name']!='Ria')]
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# ...

# %%
marks_data.set_index('Student_ID', inplace=True)
marks_data
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S13               Maria   8.215446  25.042783  16.518147  36.543154
# ...

# %%
marks_data.loc[['S04']]
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S04               David  21.160844  95.052971  35.860852  62.865185
#
#             Social_Studies
# Student_ID
# S04              95.264572

# %%
display(marks_data.iloc[[0, 4]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S05              34.041671

# %%
print(marks_data.iloc[[0,5,8]])
print(marks_data.iloc[[4,11,16]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S06              85.019761
# S09              90.483635
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
#
#             Social_Studies
# Student_ID
# S05              34.041671
# S12              71.930382
# S17               8.432155

# %%
display(marks_data.loc['S01':'S05'])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks_data.iloc[2:5])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks_data.iloc[0:5])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks_data.iloc[:5])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks_data.iloc[15:20])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks_data.iloc[15:])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks_data.iloc[1:4])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
#
#             Social_Studies
# Student_ID
# S02              80.805730
# S03              58.057612
# S04              95.264572

# %% [markdown]
# ## Cleaning Dataframe

# %%
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],  # With strings, it will become 'None'
          "temperature_f":[67.24,84.56,91.61,None,49.64]   #With numbers, it will become 'NaN'
         })
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
temps.isna()
# Out:
#    sequence  measurement_type  temperature_f
# 0     False             False          False
# 1     False             False          False
# 2     False             False          False
# 3     False              True           True
# 4     False             False          False

# %%
temps.isna().sum()
# Out:
# sequence            0
# measurement_type    1
# temperature_f       1
# dtype: int64

# %%
temps.isna().sum().sum()
# Out:
# 2

# %%
clean_temps = temps.dropna(how='any')
display (clean_temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
clean_temps_all = temps.dropna(how='all')
display(clean_temps_all)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
temps.dropna()
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
temps.dropna(axis=1)
# Out:
#    sequence
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
temps.dropna(axis='columns')
# Out:
#    sequence
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
temps['temperature_f'].cumsum()
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4    293.05
# Name: temperature_f, dtype: float64

# %%
temps['temperature_f'].cumsum(skipna=False)
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4       NaN
# Name: temperature_f, dtype: float64

# %% [markdown]
# ## Filling null values

# %%
temps.fillna(value=0, inplace=True)

# %%
display(temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %%
# Filling missing value with previous values, padding

temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps.fillna(method='pad' , inplace=True)
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4           actual          91.61
# 4         5        estimated          49.64

# %%
# Filling missing value with next value, bfill

temps1 = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps1.fillna(method='bfill' , inplace=True)
temps1
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4        estimated          49.64
# 4         5        estimated          49.64

# %%
# Filling null values with mean

temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps['temperature_f'].fillna(temps['temperature_f'].mean(), inplace=True)

# %%
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual        67.2400
# 1         2           actual        84.5600
# 2         3           actual        91.6100
# 3         4             None        73.2625
# 4         5        estimated        49.6400

# %% [markdown]
# ## Lambda Function

# %%
lambda_cube = lambda y: y*y*y
print(lambda_cube(5))
# Out:
# 125

# %%
teams = pd.DataFrame({"Region":['North','West','East','South'],
          "Team":['One','Two','One','Two'],
          "Squad":['A','B','C','D'],
          "Revenue":[7500,5500,2750,6400],
            "Cost":[5200,5100,4400,5300]})

display (teams)
# Out:
#   Region Team Squad  Revenue  Cost
# 0  North  One     A     7500  5200
# 1   West  Two     B     5500  5100
# 2   East  One     C     2750  4400
# 3  South  Two     D     6400  5300

# %%
teams['Profit'] = teams.apply(lambda x: 'Profit' if x['Revenue']>x['Cost'] else 'Loss', axis=1)
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit
# 0  North  One     A     7500  5200  Profit
# 1   West  Two     B     5500  5100  Profit
# 2   East  One     C     2750  4400    Loss
# 3  South  Two     D     6400  5300  Profit

# %%
team_map = {"One":"Red","Two":"Blue"} 
teams['Team_color'] = teams['Team'].map(team_map)
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team_color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue

# %%
teams.applymap(lambda x: len(str(x)))
# Out:
#    Region  Team  Squad  Revenue  Cost  Profit  Team_color
# 0       5     3      1        4     4       6           3
# 1       4     3      1        4     4       6           4
# 2       4     3      1        4     4       4           3
# 3       5     3      1        4     4       6           4

# %%
teams.groupby(['Profit']).max()
# Out:
#        Region Team Squad  Revenue  Cost Team_color
# Profit
# Loss     East  One     C     2750  4400        Red
# Profit   West  Two     D     7500  5300        Red

# %%
teams.groupby(['Cost']).min()
# Out:
#      Region Team Squad  Revenue  Profit Team_color
# Cost
# 4400   East  One     C     2750    Loss        Red
# 5100   West  Two     B     5500  Profit       Blue
# 5200  North  One     A     7500  Profit        Red
# 5300  South  Two     D     6400  Profit       Blue

# %%
teams.groupby(['Revenue']).mean()
# Out:
#          Cost
# Revenue
# 2750     4400
# 5500     5100
# 6400     5300
# 7500     5200

# %%
teams.groupby(['Team']).agg({'Revenue':['mean','min','max']})
# Out:
#      Revenue
#         mean   min   max
# Team
# One     5125  2750  7500
# Two     5950  5500  6400

# %% [markdown]
# ## Reset index, Set index, Reindexing

# %%
teams = pd.DataFrame({"Region":['North','West','East','South'],
          "Team":['One','Two','One','Two'],
          "Squad":['A','B','C','D'],
          "Revenue":[7500,5500,2750,6400],
            "Cost":[5200,5100,4400,5300]})

display (teams)
# Out:
#   Region Team Squad  Revenue  Cost
# 0  North  One     A     7500  5200
# 1   West  Two     B     5500  5100
# 2   East  One     C     2750  4400
# 3  South  Two     D     6400  5300

# %%
team_reindex = teams.set_index(['Region','Team'])
team_reindex
# Out:
#             Squad  Revenue  Cost
# Region Team
# North  One      A     7500  5200
# West   Two      B     5500  5100
# East   One      C     2750  4400
# South  Two      D     6400  5300

# %%
# resturcturing Teams
stacked = pd.DataFrame(team_reindex.stack())
stacked
# Out:
#                         0
# Region Team
# North  One  Squad       A
#             Revenue  7500
#             Cost     5200
# West   Two  Squad       B
#             Revenue  5500
#             Cost     5100
# East   One  Squad       C
#             Revenue  2750
#             Cost     4400
# South  Two  Squad       D
#             Revenue  6400
#             Cost     5300

# %%
#Changing order of Index columns
team_reindex_2 = teams.set_index(['Team','Region'])
team_reindex_2
# Out:
#             Squad  Revenue  Cost
# Team Region
# One  North      A     7500  5200
# Two  West       B     5500  5100
# One  East       C     2750  4400
# Two  South      D     6400  5300

# %%
stacked_2 = pd.DataFrame(team_reindex_2.stack())
stacked_2
# Out:
#                         0
# Team Region
# One  North  Squad       A
#             Revenue  7500
#             Cost     5200
# Two  West   Squad       B
#             Revenue  5500
#             Cost     5100
# One  East   Squad       C
#             Revenue  2750
#             Cost     4400
# Two  South  Squad       D
#             Revenue  6400
#             Cost     5300

# %% [markdown]
# ## Merging DataFrames

# %%
group1 = pd.DataFrame({'name': ['Alice', 'Bob', 'Charlie', 'David'],
                    'number': [1, 2, 3, 4]})
group2 = pd.DataFrame({'name': ['Charlie', 'David', 'Edward', 'Ford'],
                    'number': [3, 4, 5, 6]})

# %%
print(group1)
print(group2)
# Out:
#       name  number
# 0    Alice       1
# 1      Bob       2
# 2  Charlie       3
# 3    David       4
#       name  number
# 0  Charlie       3
# 1    David       4
# 2   Edward       5
# 3     Ford       6

# %%
group1.merge(group2, how='left', on='number')
# Out:
#     name_x  number   name_y
# 0    Alice       1      NaN
# 1      Bob       2      NaN
# 2  Charlie       3  Charlie
# 3    David       4    David

# %%
group1.merge(group2)
# Out:
#       name  number
# 0  Charlie       3
# 1    David       4

# %%
group1.merge(group2, how='inner',left_on='number',right_on='number')
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David

# %%
group1.merge(group2,how='right',left_on='number',right_on='number')
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David
# 2      NaN       5   Edward
# 3      NaN       6     Ford

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
mtc_data.head(5)
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtc_data.set_index('car_names', inplace=True)
mtc_data.head(5)
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# car_names
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# car_names
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
# Scatter plot using matplotlib
plt.scatter(x='mpg', y='hp', data=mtc_data)
plt.xlabel('MPG')
plt.ylabel('HP')
# Out:
# Text(0, 0.5, 'HP')

# %%
plt.scatter(x='mpg', y='hp', data=mtc_data, c='red')
plt.xlabel('MPG')
plt.ylabel('HP')
# Out:
# Text(0, 0.5, 'HP')

# %%
# making a cross tab with cyl as index and counts as columns
pd.crosstab(mtc_data.cyl, mtc_data.cyl)
# Out:
# cyl   4  6   8
# cyl
# 4    11  0   0
# 6     0  7   0
# 8     0  0  14

# %%
ct = pd.crosstab(mtc_data.cyl, mtc_data.cyl)

ct.plot.bar(stacked=True)    
plt.legend(title='mark')   

plt.show()

# %%
ct2 = pd.crosstab(mtc_data.cyl, mtc_data.am)

ct2.plot.bar(stacked=True)    
plt.legend(title='mark')   

plt.show()

# %%
ct3 = mtc_data.groupby('cyl')[['mpg','hp']].nunique()
ct3.plot.bar(stacked=True)    
plt.legend(title='mark')   

plt.show()

# %%
ct4 = mtc_data['cyl'].value_counts()

# %%
ct4
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
mylabels=['8','4','6']
plt.pie(ct4, labels= mylabels)
plt.title('Cyl count')
# Out:
# Text(0.5, 1.0, 'Cyl count')

# %%
plt.hist(mtc_data['mpg'], bins=10)
plt.title('mpg')
# Out:
# Text(0.5, 1.0, 'mpg')
